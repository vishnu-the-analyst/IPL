# %%
import glob
import numpy as np
csv_files = (glob.glob("C:/Users/Vishnu Kumar/Documents/IPL/raw/*info.csv"))

# %%
import pandas as pd


df_append = pd.DataFrame()

for file in csv_files:
            df_temp = pd.read_csv(file,sep='漢ழ்字', engine='python',header=None)
            df_temp['ID'] = file
            df_temp = df_temp[(df_temp[0].str.startswith('info,toss_winner')) | (df_temp[0].str.startswith('info,toss_decision'))]
            df_append = pd.concat([df_append,df_temp])

df_append = df_append.reset_index()
df_append[['info', 'attrib','value']] = df_append[0].str.split(",", expand = True)
df_append = df_append.drop(columns=['index',0,'info'])
df_append['ID'] = df_append['ID'].str[40:-9]
toss_winner = df_append[df_append['attrib']=='toss_winner'].copy()
toss_decision = df_append[df_append['attrib']=='toss_decision'].copy()
toss_winner['ID'] = toss_winner['ID'].astype('int')
toss_decision['ID'] = toss_decision['ID'].astype('int')

# %%
all_matches = pd.read_csv("C:/Users/Vishnu Kumar/Documents/IPL/raw/all_matches.csv")
# all_matches
all_matches = pd.merge(all_matches, toss_winner, how="left" ,left_on = "match_id", right_on = "ID" )
all_matches = all_matches.drop(columns=["ID", "attrib"])
all_matches = all_matches.rename(columns={"value": "toss_winner"})
all_matches = pd.merge(all_matches, toss_decision, how="left" ,left_on = "match_id", right_on = "ID" )
all_matches = all_matches.drop(columns=["ID", "attrib"])
all_matches = all_matches.rename(columns={"value": "toss_decision"})
all_matches = all_matches[all_matches['innings']<=2]
all_matches['season'] = all_matches['season'].replace(['2007/08', '2009', '2009/10', '2011' ,'2012','2018', '2019', '2020/21', '2021'], [2008,2009,2010,2011,2012,2018,2019,2020,2021])
all_matches['toss_win_batting'] = all_matches.apply(lambda x: 1 if x['toss_winner'] == x['batting_team'] else 0, axis=1)
all_matches['toss_decision'] = all_matches.apply(lambda x: 1 if x['toss_decision'] == 'bat' else 0, axis=1)
all_matches['player_dismissed'] = all_matches.apply(lambda x: 1 if x['player_dismissed'] == x['striker'] else 0, axis=1)
all_data = all_matches.copy()
# all_matches = pd.concat([all_matches, toss_winner], axis=1, join='outer', join_axes=[match_id,ID])
# Out:
# C:\Users\Vishnu Kumar\AppData\Local\Temp\ipykernel_13936\579395103.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_matches = pd.read_csv("C:/Users/Vishnu Kumar/Documents/IPL/raw/all_matches.csv")

# %%
all_for_bowlers = all_data.copy()
all_for_bowlers['ball'] = (all_for_bowlers['ball'].apply(np.floor))+1
all_for_bowlers = all_for_bowlers.drop(columns=['start_date','striker','non_striker','runs_off_bat','extras','wides','noballs','byes','legbyes','penalty','wicket_type','player_dismissed','other_wicket_type','other_player_dismissed'])
all_for_bowlers['Over_1'] = all_for_bowlers.apply(lambda x: 1 if x['ball'] == 1 else 0, axis=1)
all_for_bowlers['Over_2'] = all_for_bowlers.apply(lambda x: 2 if x['ball'] == 2 else 0, axis=1)
all_for_bowlers['Over_3'] = all_for_bowlers.apply(lambda x: 3 if x['ball'] == 3 else 0, axis=1)
all_for_bowlers['Over_4'] = all_for_bowlers.apply(lambda x: 4 if x['ball'] == 4 else 0, axis=1)
all_for_bowlers['Over_5'] = all_for_bowlers.apply(lambda x: 5 if x['ball'] == 5 else 0, axis=1)
all_for_bowlers['Over_6'] = all_for_bowlers.apply(lambda x: 6 if x['ball'] == 6 else 0, axis=1)
all_for_bowlers['Over_7'] = all_for_bowlers.apply(lambda x: 7 if x['ball'] == 7 else 0, axis=1)
all_for_bowlers['Over_8'] = all_for_bowlers.apply(lambda x: 8 if x['ball'] == 8 else 0, axis=1)
all_for_bowlers['Over_9'] = all_for_bowlers.apply(lambda x: 9 if x['ball'] == 9 else 0, axis=1)
all_for_bowlers['Over_10'] = all_for_bowlers.apply(lambda x: 10 if x['ball'] == 10 else 0, axis=1)
all_for_bowlers['Over_11'] = all_for_bowlers.apply(lambda x: 11 if x['ball'] == 11 else 0, axis=1)
all_for_bowlers['Over_12'] = all_for_bowlers.apply(lambda x: 12 if x['ball'] == 12 else 0, axis=1)
all_for_bowlers['Over_13'] = all_for_bowlers.apply(lambda x: 13 if x['ball'] == 13 else 0, axis=1)
all_for_bowlers['Over_14'] = all_for_bowlers.apply(lambda x: 14 if x['ball'] == 14 else 0, axis=1)
all_for_bowlers['Over_15'] = all_for_bowlers.apply(lambda x: 15 if x['ball'] == 15 else 0, axis=1)
all_for_bowlers['Over_16'] = all_for_bowlers.apply(lambda x: 16 if x['ball'] == 16 else 0, axis=1)
all_for_bowlers['Over_17'] = all_for_bowlers.apply(lambda x: 17 if x['ball'] == 17 else 0, axis=1)
all_for_bowlers['Over_18'] = all_for_bowlers.apply(lambda x: 18 if x['ball'] == 18 else 0, axis=1)
all_for_bowlers['Over_19'] = all_for_bowlers.apply(lambda x: 19 if x['ball'] == 19 else 0, axis=1)
all_for_bowlers['Over_20'] = all_for_bowlers.apply(lambda x: 20 if x['ball'] == 20 else 0, axis=1)
# all_for_bowlers

# %%
all_for_bowlers = pd.pivot_table(all_for_bowlers, values =['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20'], index =['match_id', 'season','venue','innings','batting_team','bowling_team','bowler','toss_winner','toss_decision','toss_win_batting'], aggfunc = np.max).reset_index()
# all_for_bowlers = pd.pivot_table(all_for_bowlers, values=['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20'], index=['match_id','venue','innings','bowler','batting_team','bowling_team'], aggfunc=np.sum).reset_index()

all_for_bowlers['largest'] = all_for_bowlers[['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20']].apply(lambda x: max([val for val in x if val != 0]), axis=1)
all_for_bowlers['second_largest'] = all_for_bowlers[['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20']].apply(lambda x: sorted([val for val in x if val != 0])[-2] if len([val for val in x if val != 0]) >= 2 else np.nan, axis=1)
all_for_bowlers['third_largest'] = all_for_bowlers[['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20']].apply(lambda x: sorted([val for val in x if val != 0])[-3] if len([val for val in x if val != 0]) >= 3 else np.nan, axis=1)
all_for_bowlers['fourth_largest'] = all_for_bowlers[['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20']].apply(lambda x: sorted([val for val in x if val != 0])[-4] if len([val for val in x if val != 0]) >= 4 else np.nan, axis=1)
all_for_bowlers = all_for_bowlers.drop(columns=['Over_1', 'Over_2', 'Over_3', 'Over_4', 'Over_5', 'Over_6', 'Over_7', 'Over_8', 'Over_9', 'Over_10', 'Over_11', 'Over_12', 'Over_13', 'Over_14', 'Over_15', 'Over_16', 'Over_17', 'Over_18', 'Over_19', 'Over_20','toss_winner','toss_decision','toss_win_batting'])

# %%
all_for_bowlers = all_for_bowlers.drop(columns=['season','match_id'])

# %%
all_for_bowlers = all_for_bowlers.rename(columns={"bowler": "Bowler Name","bowling_team" : "Team Name","batting_team": "Opposite Team Name","innings":"Bowling Innings","venue":"Venue",'largest':'over_1','second_largest':'over_2','third_largest':'over_3','fourth_largest':'over_4' })

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Embedding
from keras.optimizers import Adam
from keras.losses import mean_squared_error
from keras.layers import Flatten

# Load the dataset
df = all_for_bowlers.copy()

# one-hot encode categorical features
df = pd.get_dummies(df, columns=['Bowler Name', 'Team Name', 'Opposite Team Name','Venue','Bowling Innings'])

df = df.fillna(0)

# normalize the data
cols_to_normalize = df.columns[:4]
df[cols_to_normalize] = (df[cols_to_normalize]-df[cols_to_normalize].min())/(df[cols_to_normalize].max()-df[cols_to_normalize].min())

# split the dataset into train and test sets
train_set = df.sample(frac=0.8, random_state=42)
test_set = df.drop(train_set.index)

# extract the features and labels
X_train = train_set.iloc[:, 1:].values
y_train = train_set.iloc[:, 0:1].values
X_test = test_set.iloc[:, 1:].values
y_test = test_set.iloc[:, 0:1].values

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# create a neural network model
model = Sequential()

# add a dense layer with 128 units and relu activation
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))

# add dropout regularization
model.add(Dropout(0.2))

# add another dense layer with 64 units and relu activation
model.add(Dense(64, activation='relu'))

# add output layer with sigmoid activation
model.add(Dense(1, activation='sigmoid'))  # output 20 probabilities for 20 overs

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# predict on test data
y_pred = model.predict(X_test)

# evaluate the model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/50
# 225/225 [==============================] - 2s 4ms/step - loss: 0.5140 - accuracy: 0.1320 - val_loss: 0.4921 - val_accuracy: 0.1370
# Epoch 2/50
# 225/225 [==============================] - 1s 3ms/step - loss: 0.4865 - accuracy: 0.1332 - val_loss: 0.4887 - val_accuracy: 0.1364
# Epoch 3/50
# 225/225 [==============================] - 1s 3ms/step - loss: 0.4800 - accuracy: 0.1335 - val_loss: 0.4888 - val_accuracy: 0.1370
# Epoch 4/50
# 225/225 [==============================] - 1s 3ms/step - loss: 0.4752 - accuracy: 0.1346 - val_loss: 0.4878 - val_accuracy: 0.1364
# Epoch 5/50
# 225/225 [==============================] - 1s 4ms/step - loss: 0.4708 - accuracy: 0.1352 - val_loss: 0.4888 - val_accuracy: 0.1370
# Epoch 6/50
# 225/225 [==============================] - 1s 3ms/step - loss: 0.4669 - accuracy: 0.1356 - val_loss: 0.4901 - val_accuracy: 0.1370
# Epoch 7/50
# ...

# %%
# Use the model to predict the probability of a bowler bowling a particular combination of overs
input_data = {'bowler_name': 'John Smith', 'team_name': 'Australia', 'opposite_team_name': 'England', 'venue': 'Lord\'s', 'bowling_innings': 1, 'over_1': 1, 'over_2': 3}
input_df = pd.DataFrame(input_data, index=[0])
input_df[cat_cols] = le.transform(input_df[cat_cols])
input_df[onehot_cols] = oh.transform(input_df[onehot_cols])
probs = model.predict(input_df)

# Calculate the probability of a specific combination
target_combination = [2, 4, 6, 8]
prob = probs[np.arange(len(target_combination)), target_combination].prod()
print('The probability of the bowler bowling overs {} is {:.4f}'.format(target_combination, prob))
